# %% [markdown]
# # Examen Inteligencia Artificial

# %% [markdown]
# Diseñe y desarrolle un sistema recopilador que permita obtener las noticias o facebook de los candidatos y almacenar dentro de una base de datos orientados a grafos:
# Webscraping es la técnica de extraer datos contenidos en un formato no estructurado en una página web y llevarlos a una estructura fácil de usar.
# Es por ello, que se desea crear nuevos métodos que permitan la recopilación masiva de informaciones para su posterior estudio y correlación en forma de big data.
# En base a ello, vamos a obtener los datos de lo que esta hablando las noticias de los candidatos dentro del Ecuador y almacenar los datos dentro de una base de datos orientadas a grafos.
#
# ◦	Generar un modelo que permita obtener y almacenar los datos en los grafos.
# ◦	Vincular los datos con el candidato seleccionado.
# ◦	Se debe tener al menos 1000 nodos generados, en caso de tener estos datos seleccionar al partido (UNES) (UNES AZUAY) (Candidato Presidencial)
# ◦	Obtener de la noticia: el Link, mensaje, fecha
# ◦	Facebook: Comentarios, Publicaciones, Amigos, Likes, Seguidores, etc.
# ◦	No se debe repetir los candidatos a asambleístas dentro del Foro del partido político de UNES AZUAY (10 primeros) .
# ◦	Se puede utilizar cualquier herramienta o procesamiento para el WebScarping.
# ◦	Generar sus análisis, conclusiones y recomendaciones en base a  los datos

# %%
from neo4j import GraphDatabase

class Neo4jService(object):

    def __init__(self, uri, user, password):
        self._driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self._driver.close()      
    
    def crear_cabecera(self, tx, nombre):
        tx.run("CREATE (:Cabecera {nombre: $nombre})", nombre=nombre)
    
    def crear_candidato(self, tx, nombre):
        tx.run("CREATE (:Candidato {nombre: $nombre})", nombre=nombre)

    def crear_noticias(self, tx, nombre):
        tx.run("CREATE (:Noticias {nombre: $nombre})", nombre=nombre)
    
    def crear_links(self, tx, nombre):
        tx.run("CREATE (:Links {nombre: $nombre})", nombre=nombre)
        
    def crear_contenido(self, tx, nombre):
        tx.run("CREATE (:Contenido {nombre: $nombre})", nombre=nombre)
        
    def crear_titulo(self, tx, nombre):
        tx.run("CREATE (:Titulo {nombre: $nombre})", nombre=nombre)

    def crear_fecha(self, tx, nombre):
        tx.run("CREATE (:Fecha {nombre: $nombre})", nombre=nombre)
        
    def crear_relacion_noticia(self, tx, nombre_noticias, nombre_noticia):
        tx.run("MATCH (a:Noticias {nombre: $nombre_noticias}) "
               "MATCH (b:Contenido {nombre: $nombre_noticia}) "
               "MERGE (a)-[:Noticias]->(b)",
               nombre_noticias=nombre_noticias, nombre_noticia=nombre_noticia)
    
    def crear_relacion_cabeceras(self, tx, nombre_cabecera, nombre_titulo):
        tx.run("MATCH (a:Cabecera {nombre: $nombre_cabecera}) "
               "MATCH (b:Titulo {nombre: $nombre_titulo}) "
               "MERGE (a)-[:TituloNoticia]->(b)",
               nombre_cabecera=nombre_cabecera, nombre_titulo=nombre_titulo)
    
    def crear_relacion_fecha(self, tx, nombre_links, nombre_fecha):
        tx.run("MATCH (a:Links {nombre: $nombre_links}) "
               "MATCH (b:Fecha {nombre: $nombre_fecha}) "
               "MERGE (a)-[:Fecha]->(b)",
               nombre_links=nombre_links, nombre_fecha=nombre_fecha)

    #relacion de candidato   cabecera links noticias 
    def crear_relacion_candidato_titulo(self, tx, nombre_candidato, nombre_titulo):
        tx.run("MATCH (a:Candidato {nombre: $nombre_candidato}) "
               "MATCH (b:Cabecera {nombre: $nombre_titulo}) "
               "MERGE (a)-[:Candidato_Titulo]->(b)",
               nombre_candidato=nombre_candidato, nombre_titulo=nombre_titulo)
        
    def crear_relacion_candidato_fecha(self, tx, nombre_candidato, nombre_fecha):
        tx.run("MATCH (a:Candidato {nombre: $nombre_candidato}) "
               "MATCH (b:Links {nombre: $nombre_fecha}) "
               "MERGE (a)-[:Candidato_Fecha]->(b)",
               nombre_candidato=nombre_candidato, nombre_fecha=nombre_fecha)
    
    def crear_relacion_candidato_contenido(self, tx, nombre_candidato, nombre_noticias):
        tx.run("MATCH (a:Candidato {nombre: $nombre_candidato}) "
               "MATCH (b:Noticias {nombre: $nombre_noticias}) "
               "MERGE (a)-[:Candidato_Noticias]->(b)",
               nombre_candidato=nombre_candidato, nombre_noticias=nombre_noticias)
        
print("Ejecucion correcta")
# Out:
# ejecucion correcta

# %%
import requests
from bs4 import BeautifulSoup

neo4j = Neo4jService('bolt://localhost:7687', 'neo4j', 'examen')
with neo4j._driver.session() as session:

    session.write_transaction(neo4j.crear_candidato , "Candidato Manuel Alvarado")
    session.write_transaction(neo4j.crear_cabecera , "Titulos")
    session.write_transaction(neo4j.crear_links , "Fecha")
    session.write_transaction(neo4j.crear_noticias , "Noticias")
k=0
with open("C:/Users/esteb/Desktop/busqueda.txt","r") as archivo:
        
    for linea in archivo:

        b=0

        page = requests.get(linea)

        soup = BeautifulSoup(page.content,'html.parser')
        #print(soup.prettify())


        #result =soup.find_all("a href")
        #titulos
        titulos =soup.find_all("div",{"class":"BNeawe vvjwJb AP7Wnd"})
        #Contenido
        contenidohtml =soup.find_all("div",{"class":"BNeawe s3v9rd AP7Wnd"})
        #Fecha
        fecha =soup.find_all("span",{"class":"r0bn4c rQMQod"})
        
        a=0

        tituloNeo=list()
        for i in titulos:
            tituloNeo.append(i.text)

        descripcion=list()
        for i in contenidohtml:
            descripcion.append(i.text)
            #print(link)
            
#descripcion filtrada
        descripcionAux=list()    
        for elemento in descripcion:
            if((a%2)==0):
                descripcionAux.append(descripcion[a])
            a=a+1
            

        fechaNeo=list()
        for i in fecha:
            fechaNeo.append(i.text)

        for elemento in tituloNeo:
            session.write_transaction(neo4j.crear_titulo , elemento)
            #print(elemento)
            
        #Descripcion print("descripcion")
        for elemento1 in descripcionAux:
            session.write_transaction(neo4j.crear_contenido , elemento1)
            #print(elemento1)
        
        for elemento2 in fechaNeo:
            if((a%2)==0):
                session.write_transaction(neo4j.crear_fecha , elemento2)
            a=a+1
            

#relaciones
        #relacion de descripcion
        for total in descripcionAux:
            session.write_transaction(neo4j.crear_relacion_noticia, "Noticias", total)  
            
        #relacion de Fecha               
        for date in fechaNeo:
            session.write_transaction(neo4j.crear_relacion_fecha, "Fecha", date)  
        
        #relacion de Titulo  
        for titul in tituloNeo:
            session.write_transaction(neo4j.crear_relacion_cabeceras, "Titulos", titul) 
            
            
session.write_transaction(neo4j.crear_relacion_candidato_titulo, "Candidato Manuel Alvarado", "Titulos")
session.write_transaction(neo4j.crear_relacion_candidato_contenido, "Candidato Manuel Alvarado", "Noticias")
session.write_transaction(neo4j.crear_relacion_candidato_fecha, "Candidato Manuel Alvarado", "Fecha")
print("Fin del proceso")
# Out:
# 1 https://www.google.com/search?q=candidato+a+asambleista+MANUEL+ALVARADO
#
# resultado de la busqueda links
# 2 https://www.google.com/search?q=candidato+a+asambleista+MANUEL+ALVARADO+facebook
#
# resultado de la busqueda links
# 3 https://www.google.com/search?q=candidato+a+asambleista+MANUEL+ALVARADO+Titter
#
# resultado de la busqueda links
# 4 https://www.google.com/search?q=candidato+a+asambleista+MANUEL+ALVARADO+blogs
#
# resultado de la busqueda links
# 5 https://www.google.com/search?q=candidato+a+asambleista+MANUEL+ALVARADO+noticias
#
# resultado de la busqueda links
# 6 https://www.google.com/search?q=candidato+a+asambleista+MANUEL+ALVARADO+polemica
#
# resultado de la busqueda links
# 7 https://www.google.com/search?q=candidato+a+asambleista+MANUEL+ALVARADO+elecciones&oq=candidato+a+asambleista+MANUEL+ALVARADO+elecciones
#
# resultado de la busqueda links
# 8 https://www.google.com/search?q=candidato+a+asambleista+MANUEL+ALVARADO+informacion&oq=candidato+a+asambleista+MANUEL+ALVARADO+informacion
#
# resultado de la busqueda links
# 9 https://www.google.com/search?q=candidato+a+asambleista+MANUEL+ALVARADO+tendencia&oq=candidato+a+asambleista+MANUEL+ALVARADO+tendencia
#
# resultado de la busqueda links
# 10 https://www.google.com/search?q=candidato+a+asambleista+MANUEL+ALVARADO+propuesta+electoral
#
# resultado de la busqueda links
# 11 https://www.google.com/search?q=candidato+a+asambleista+MANUEL+ALVARADO+plan+electoral+2021
#
# resultado de la busqueda links
# 12 https://www.google.com/search?q=candidato+a+asambleista+MANUEL+ALVARADO+partido
#
# resultado de la busqueda links
# 13 https://www.google.com/search?q=candidato+a+asambleista+MANUEL+ALVARADO+noticias+partido
#
# resultado de la busqueda links
# 14 https://www.google.com/search?q=candidato+a+asambleista+MANUEL+ALVARADO+redes+sociales
#
# resultado de la busqueda links
# 15 https://www.google.com/search?q=MANUEL+ALVARADO+ecuador+asambleista&oq=MANUEL+ALVARADO+ecuador+asambleista
#
# resultado de la busqueda links
# 16 https://www.google.com/search?q=MANUEL+ALVARADO+ecuador+asambleista+azuay&oq=MANUEL+ALVARADO+ecuador+asambleista+azuay
#
# resultado de la busqueda links
# 17 https://www.google.com/search?q=MANUEL+ALVARADO+ecuador+candidato+asambleista+azuay&oq=MANUEL+ALVARADO+ecuador+candidato+asambleista+azuay
#
# resultado de la busqueda links
# 18 https://www.google.com/search?q=MANUEL+ALVARADO+ecuador+candidato+elecciones+2021&oq=MANUEL+ALVARADO+ecuador+candidato+elecciones+2021
#
# resultado de la busqueda links
# 19 https://www.google.com/search?q=historia+de+manuel+alvarado+candidato+ecuador&oq=historia+de+manuel+alvarado+candidato
#
# resultado de la busqueda links
# 20 https://www.google.com/search?q=quien+es+el+candidao+manuel+alvarado+de+ecuador&oq=quien+es+el+candidao+manuel+alvarado
#
# resultado de la busqueda links
# 21 https://www.google.com/search?q=polemicas+con+el+candidato+manuel+alvarado+azuay&oq=polemicas+con+el+candidato+manuel+alvarado+azuay
#
# resultado de la busqueda links
# 22 https://www.google.com/search?q=manuelalvaradoazuay
#
# resultado de la busqueda links
# 23 https://www.google.com/search?q=%23manuelalvaradocandidato&oq=%23manuelalvaradocandidato
#
# resultado de la busqueda links
# 24 https://www.google.com/search?q=%23manuelalvaradocuenca&oq=%23manuelalvaradocuenca
#
# resultado de la busqueda links
# 25 https://www.google.com/search?q=elecciones+2021+ecuador+manuel+alvarado&oq=elecciones+2021+ecuador+manuel+alvarado
#
# resultado de la busqueda links
# 26 https://www.google.com/search?q=candidato+manuel+alvarado+asambleista&ei=mHreX8fmI6zY5gLEr7uQCg&start=10&sa=N&ved=2ahUKEwjHkquRiNvtAhUsrFkKHcTXDqIQ8NMDegQIBRBH&biw=1536&bih=754
#
# resultado de la busqueda links
# 27 https://www.google.com/search?q=candidato+manuel+alvarado+asambleista&ei=tnreX-XDOLCC5wLL6ZegDA&start=20&sa=N&ved=2ahUKEwjl9uafiNvtAhUwwVkKHcv0BcQ4ChDw0wN6BAgFEEc&biw=1536&bih=754
#
# resultado de la busqueda links
# 28 https://www.google.com/search?q=candidato+manuel+alvarado+asambleista&ei=v3reX4rlGont5gKapYaYCQ&start=30&sa=N&ved=2ahUKEwjKwO6jiNvtAhWJtlkKHZqSAZM4FBDw0wN6BAgFEEc&biw=1536&bih=754
#
# resultado de la busqueda links
# 29 https://www.google.com/search?q=candidato+manuel+alvarado+asambleista&ei=xXreX7qHOofr5gKI5YuYBQ&start=40&sa=N&ved=2ahUKEwj6_fumiNvtAhWHtVkKHYjyAlM4HhDw0wN6BAgFEEc&biw=1536&bih=754
#
# resultado de la busqueda links
# 30 https://www.google.com/search?q=candidato+manuel+alvarado+asambleista&ei=zHreX7yJJMGD5wL414zoDQ&start=50&sa=N&ved=2ahUKEwi8n5GqiNvtAhXBwVkKHfgrA904KBDw0wN6BAgFEEU&biw=1536&bih=754
#
# resultado de la busqueda links
# 31 https://www.google.com/search?q=candidato+manuel+alvarado+asambleista+noticias&ei=NH7eX_mEGuyN5wK18ZfQDQ&start=40&sa=N&ved=2ahUKEwj57u3Ji9vtAhXsxlkKHbX4Bdo4MhDy0wN6BAgOEEA&biw=1536&bih=754
#
# resultado de la busqueda links
# 32 https://www.google.com/search?q=candidato+manuel+alvarado+asambleista+noticias&ei=N37eX4PiN4qc5gLJt4CwAQ&start=30&sa=N&ved=2ahUKEwjD2cLLi9vtAhUKjlkKHckbABY4KBDy0wN6BAgFED4&biw=1536&bih=754
#
# resultado de la busqueda links
# 33 https://www.google.com/search?q=candidato+manuel+alvarado+asambleista+noticias&ei=RH7eX6CBOMPt5gKh_beQCg&start=20&sa=N&ved=2ahUKEwigs9zRi9vtAhXDtlkKHaH-DaI4HhDy0wN6BAgFEDw&biw=1536&bih=754
#
# resultado de la busqueda links
# 34 https://www.google.com/search?q=candidato+manuel+alvarado+asambleista+noticias&ei=S37eX_PDCJHG5gLS1rOAAg&start=10&sa=N&ved=2ahUKEwizldjUi9vtAhURo1kKHVLrDCA4FBDy0wN6BAgFEDo&biw=1536&bih=754
#
# resultado de la busqueda links
# 35 https://www.google.com/search?q=candidato+manuel+alvarado+asambleista+partido+politico&ei=X37eX52CLMWw5wKD66boAQ&start=10&sa=N&ved=2ahUKEwjdrcDei9vtAhVF2FkKHYO1CR0Q8tMDegQIBRA5&biw=1536&bih=754
#
# resultado de la busqueda links
# 36 https://www.google.com/search?q=candidato+manuel+alvarado+asambleista+partido+politico&ei=Yn7eX7-iK5Cy5gLBxKDADg&start=20&sa=N&ved=2ahUKEwi_2_bfi9vtAhUQmVkKHUEiCOg4ChDy0wN6BAgFEDs&biw=1536&bih=754
#
# resultado de la busqueda links
# 37 https://www.google.com/search?q=candidato+manuel+alvarado+asambleista+partido+politico&ei=dH7eX8PePKPx5gLKiKNo&start=30&sa=N&ved=2ahUKEwjD6NLoi9vtAhWjuFkKHUrECA04FBDy0wN6BAgFED0&biw=1536&bih=754
#
# resultado de la busqueda links
# 38 https://www.google.com/search?q=candidato+manuel+alvarado+asambleista+partido+propuestas+politica&ei=zn_eX_CaF4Oa5gKyiYWQCw&start=10&sa=N&ved=2ahUKEwjwuauNjdvtAhUDjVkKHbJEAbIQ8tMDegQIBRA5&biw=1536&bih=754
#
# resultado de la busqueda links
# 39 https://www.google.com/search?q=candidato+manuel+alvarado+asambleista+partido+propuestas+politica&ei=03_eX_zGIbGb5wK73rLQCA&start=20&sa=N&ved=2ahUKEwi8_OaPjdvtAhWxzVkKHTuvDIo4ChDy0wN6BAgFEDs&biw=1536&bih=754
#
# resultado de la busqueda links
# 40 https://www.google.com/search?q=candidato+manuel+alvarado+asambleista+partido+propuestas+politica&ei=4H_eX8XJL43Y5gKimbUo&start=30&sa=N&ved=2ahUKEwjFuY6WjdvtAhUNrFkKHaJMDQU4FBDy0wN6BAgFED0&biw=1536&bih=754
#
# resultado de la busqueda links
# 41 https://www.google.com/search?q=candidato+manuel+alvarado+asambleista+partido+propuestas+politica&ei=6H_eX6npLYmm5wKp5pfAAg&start=40&sa=N&ved=2ahUKEwip_fSZjdvtAhUJ01kKHSnzBSg4HhDy0wN6BAgFED8&biw=1536&bih=754
#
# resultado de la busqueda links
# 42 https://www.google.com/search?q=candidato+manuel+alvarado+asambleista+partido+propuestas+politica&ei=73_eX6WVLq_y5gKQ4KP4Aw&start=50&sa=N&ved=2ahUKEwjlyKCdjdvtAhUvuVkKHRDwCD84KBDy0wN6BAgFEEE&biw=1536&bih=754
#
# resultado de la busqueda links
# 43 https://www.google.com/search?q=candidato+manuel+alvarado+asambleista+partido+propuestas+politica&ei=9n_eX9-XAsWB5wLl4LWACg&start=60&sa=N&ved=2ahUKEwjf6p-gjdvtAhXFwFkKHWVwDaA4MhDy0wN6BAgFEEM&biw=1536&bih=754
#
# resultado de la busqueda links
# 44 https://www.google.com/search?q=manuel+alvarado+asambleista+partido+propuestas+politicas+publica&ei=DoDeX-jdArDz5gLlqqTADw&start=90&sa=N&ved=2ahUKEwjonNmrjdvtAhWwuVkKHWUVCfgQ8tMDegQIBRBJ&biw=1536&bih=754
#
# resultado de la busqueda links
# 45 https://www.google.com/search?q=manuel+alvarado+asambleista+partido+propuestas+politicas+publica&ei=EYDeX8qnM4GB5wLat4DADQ&start=80&sa=N&ved=2ahUKEwiK9MCtjdvtAhWBwFkKHdobANg4WhDy0wN6BAgFEEg&biw=1536&bih=754
#
# resultado de la busqueda links
# 46 https://www.google.com/search?q=manuel+alvarado+asambleista+partido+propuestas+politicas+publica&ei=GYDeX7j3AsqW5gKDrg8&start=70&sa=N&ved=2ahUKEwj45_iwjdvtAhVKi1kKHQPXAwA4UBDy0wN6BAgFEEY&biw=1536&bih=754
# resultado de la busqueda links
# 47 https://www.google.com/search?q=manuel+alvarado+asambleista+partido+propuestas+politicas+publica&ei=H4DeX_y1GcS85gL3j7mYAg&start=60&sa=N&ved=2ahUKEwi8wf2zjdvtAhVEnlkKHfdHDiM4RhDy0wN6BAgFEEI&biw=1536&bih=754
#
# resultado de la busqueda links
# 48 https://www.google.com/search?q=manuel+alvarado+asambleista+partido+propuestas+politicas+publica&ei=JoDeX93AG8OA5wLWmLn4Bw&start=50&sa=N&ved=2ahUKEwjd66q3jdvtAhVDwFkKHVZMDn84PBDy0wN6BAgFEEA&biw=1536&bih=754
#
# resultado de la busqueda links
# 49 https://www.google.com/search?q=manuel+alvarado+asambleista+partido+propuestas+politicas+publica&ei=K4DeX_GyF4qo5gK1go6QBA&start=40&sa=N&ved=2ahUKEwix9Ne5jdvtAhUKlFkKHTWBA0I4MhDy0wN6BAgFEEA&biw=1536&bih=754
#
# resultado de la busqueda links
# 50 https://www.google.com/search?q=manuel+alvarado+asambleista+partido+propuestas+politicas+publica&ei=MYDeX5fqCo_X5gKi5LmIBQ&start=30&sa=N&ved=2ahUKEwjXxrm8jdvtAhWPq1kKHSJyDlE4KBDy0wN6BAgFED4&biw=1536&bih=754
# resultado de la busqueda links
# fin del proceso
